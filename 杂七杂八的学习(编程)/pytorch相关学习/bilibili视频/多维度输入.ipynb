# %% [markdown]
# 多输入
# 竖着叫特征(feature)，横着叫 sample
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %%
import torch

# %%
class Model(torch.nn.Module):
    def __inti__(self):
        super(Model, self).__init__()
        # 这里修改维度
        self.linear = torch.nn.Linear(8.1)
        self.sigmoid = torch.nn.Sigmoid()
        
    def forward(self, x):
        x = self.sigmoid(self.linear(x))
        return x
mode = Model()

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %%
import numpy as np

# %%
xy = np.loadtxt('diabetes.csv.gz', delimiter=',', dtype=np.float32)

# %%
x_data = torch.from_numpy(xy[:,:-1])
# 如果不给-1加括号的话，拿出来的就是向量而不是矩阵了
y_data = torch.from_numpy(xy[:,[-1]])

# %%
class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.linear1 = torch.nn.Linear(8,6)
        self.linear2 = torch.nn.Linear(6,4)
        self.linear3 = torch.nn.Linear(4,1)
        self.sigmoid = torch.nn.Sigmoid()  # 这里改激活函数 比如 nn.ReLu
        
    def forward(self, x):
        x = self.sigmoid(self.linear1(x))
        x = self.sigmoid(self.linear2(x))
        x = self.sigmoid(self.linear3(x))
        return x
model = Model()

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %%
cirterion = torch.nn.BCELoss(size_average=True)
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)
# Out:
# D:\Python\Python36\Lib\site-packages\torch\nn\_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))

# %%
for epoch in range(100):
    y_pred = model(x_data)
    loss = cirterion(y_pred, y_data)
    print(epoch, loss.item())
    
    optimizer.zero_grad()
    loss.backward()
    
    optimizer.step()
# Out:
# 0 0.7250274419784546
# 1 0.7173031568527222
# 2 0.7103159427642822
# 3 0.7039992213249207
# 4 0.6982903480529785
# 5 0.693132758140564
# 6 0.6884745359420776
# 7 0.6842684149742126
# 8 0.6804711222648621
# 9 0.6770431399345398
# 10 0.673949122428894
# 11 0.671156644821167
# 12 0.6686362028121948
# 13 0.6663616299629211
# 14 0.664309024810791
# 15 0.6624562740325928
# 16 0.6607843041419983
# 17 0.6592749357223511
# 18 0.6579127311706543
# 19 0.6566826701164246
# 20 0.6555724740028381
# 21 0.6545699238777161
# 22 0.6536649465560913
# 23 0.6528472900390625
# 24 0.6521090865135193
# 25 0.6514422297477722
# 26 0.6508399248123169
# 27 0.6502957344055176
# 28 0.6498040556907654
# 29 0.6493597030639648
# 30 0.6489582061767578
# 31 0.6485953330993652
# 32 0.648267388343811
# 33 0.6479708552360535
# 34 0.647702693939209
# 35 0.6474602818489075
# 36 0.647240936756134
# 37 0.6470426917076111
# 38 0.6468633413314819
# 39 0.6467011570930481
# 40 0.6465542316436768
# 41 0.646421492099762
# 42 0.6463013291358948
# 43 0.6461926102638245
# 44 0.646094024181366
# 45 0.6460050344467163
# 46 0.6459242701530457
# 47 0.6458512544631958
# 48 0.6457851529121399
# 49 0.6457250714302063
# 50 0.6456709504127502
# 51 0.6456215381622314
# 52 0.6455771923065186
# 53 0.6455366015434265
# 54 0.6454999446868896
# 55 0.6454669237136841
# 56 0.6454365849494934
# 57 0.6454094052314758
# 58 0.6453845500946045
# 59 0.6453620791435242
# 60 0.645341694355011
# 61 0.6453230381011963
# 62 0.6453062891960144
# 63 0.6452909708023071
# 64 0.6452770829200745
# 65 0.645264208316803
# 66 0.6452527642250061
# 67 0.6452422142028809
# 68 0.6452326774597168
# 69 0.6452242136001587
# 70 0.6452159881591797
# 71 0.6452087759971619
# 72 0.6452021598815918
# 73 0.6451960206031799
# 74 0.6451904773712158
# 75 0.6451854109764099
# 76 0.6451807022094727
# 77 0.6451764702796936
# 78 0.6451724767684937
# 79 0.6451689004898071
# 80 0.6451655030250549
# 81 0.6451625227928162
# 82 0.6451597213745117
# 83 0.645156979560852
# 84 0.6451546549797058
# 85 0.6451523303985596
# 86 0.6451500654220581
# 87 0.6451480388641357
# 88 0.6451462507247925
# 89 0.6451444625854492
# 90 0.6451429128646851
# 91 0.6451413035392761
# 92 0.6451399326324463
# 93 0.6451384425163269
# 94 0.6451373100280762
# 95 0.6451359987258911
# 96 0.6451347470283508
# 97 0.6451336145401001
# 98 0.6451325416564941
# 99 0.645131528377533

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
